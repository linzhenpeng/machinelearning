# %% [markdown]
# 资料:
#
# (强烈推荐)<统计学习方法>
#
# (推荐)[梯度提升树(GBDT)原理小结](https://www.cnblogs.com/pinard/p/6140514.html)
# [scikit-learn 梯度提升树(GBDT)调参小结](http://www.cnblogs.com/pinard/p/6143927.html)
# [RF、GBDT、XGBoost面试级整理](http://blog.csdn.net/qq_28031525/article/details/70207918)
# (推荐)[gbdt原理](https://wenku.baidu.com/view/f3da60b4951ea76e58fafab069dc5022aaea463e.html)
# [GBDT算法](https://wenku.baidu.com/view/26d05e4ae418964bcf84b9d528ea81c758f52e68.html?rec_flag=default&mark_pay_doc=2&mark_rec_page=1&mark_rec_position=3&mark_rec=view_r_1&clear_uda_param=1)

# %% [markdown]
# ## GBDT(梯度提升树)

# %% [markdown]
# ### 概要

# %% [markdown]
# 梯度提升树(Gradient Boosting Decison Tree, 以下简称GBDT)。GBDT有很多简称，有GBT（Gradient Boosting Tree）, GTB（Gradient Tree Boosting ）， GBRT（Gradient Boosting Regression Tree）, MART(Multiple Additive Regression Tree)，其实都是指的同一种算法，本文统一简称GBDT。
#
# 相关笔记  [Adaboost](https://github.com/linzhenpeng/machinelearning/blob/master/Adaboost/Adaboost.ipynb) [决策树](https://github.com/linzhenpeng/machinelearning/blob/master/decisionTree/decisionTree.ipynb)

# %% [markdown]
# #### 原理

# %% [markdown]
# GBDT与传统的Boosting区别较大，它的每一次计算都是为了减少上一次的残差，而为了消除残差，我们可以在残差减小的梯度方向上建立模型,所以说，在GradientBoost中，每个新的模型的建立是为了使得之前的模型的残差往梯度下降的方法，与传统的Boosting中关注正确错误的样本加权有着很大的区别。
# 　　在GradientBoosting算法中，关键就是利用损失函数的负梯度方向在当前模型的值作为残差的近似值，进而拟合一棵CART回归树。
# 　　GBDT的会累加所有树的结果，而这种累加是无法通过分类完成的，因此GBDT的树都是CART回归树，而不是分类树（尽管GBDT调整后也可以用于分类但不代表GBDT的树为分类树）。
#
#   GBDT也是集成学习Boosting家族的成员，但是却和传统的Adaboost有很大的不同。回顾下Adaboost，我们是利用前一轮迭代弱学习器的误差率来更新训练集的权重，这样一轮轮的迭代下去。GBDT也是迭代，使用了前向分布算法，但是弱学习器限定了只能使用CART回归树模型，同时迭代思路和Adaboost也有所不同。
#
# 　　　　在GBDT的迭代中，假设我们前一轮迭代得到的强学习器是$f_{t−1}(x)$, 损失函数是$L(y,f_{t−1}(x))$, 我们本轮迭代的目标是找到一个CART回归树模型的弱学习器$h_t(x)$，让本轮的损失损失$L(y,f_t(x)=L(y,f_{t−1}(x)+h_t(x))$最小。也就是说，本轮迭代找到决策树，要让样本的损失尽量变得更小。
#
# 　　　　GBDT的思想可以用一个通俗的例子解释，假如有个人30岁，我们首先用20岁去拟合，发现损失有10岁，这时我们用6岁去拟合剩下的损失，发现差距还有4岁，第三轮我们用3岁拟合剩下的差距，差距就只有一岁了。如果我们的迭代轮数还没有完，可以继续迭代下面，每一轮迭代，拟合的岁数误差都会减小。

# %% [markdown]
# #### 应用

# %% [markdown]
# GBDT除了本身性能优异还可以用于特征选择和特征组合,其可以发现多种有区分性的特征以及特征组合,决策树的路径可以直接作为LR或者FM输入特征使用,省去了人工寻找特征,特征组合的步骤.

# %% [markdown]
# #### 优缺点

# %% [markdown]
# GBDT主要的优点有：
#
# 　　　　1) 可以灵活处理各种类型的数据，包括连续值和离散值。
#
# 　　　　2) 在相对少的调参时间情况下，预测的准备率也可以比较高。这个是相对SVM来说的。
#
# 　　　　3）使用一些健壮的损失函数，对异常值的鲁棒性非常强。比如 Huber损失函数和Quantile损失函数。
#
# GBDT的主要缺点有：
#
# 　　　　1)由于弱学习器之间存在依赖关系，难以并行训练数据。不过可以通过自采样的SGBT来达到部分并行。

# %% [markdown]
# ### 提升树(来自统计学习方法)

# %% [markdown]
# 提升树是以分类回归树为基本分类器的提升方法,提升树被认为是统计学习中性能最好的方法之一

# %%
from IPython.core.display import Image, display
display(Image(filename='images/boosttree1.png'))
display(Image(filename='images/boosttree2.png'))
display(Image(filename='images/boosttree3.png'))
display(Image(filename='images/boosttree4.png'))
display(Image(filename='images/boosttree5.png'))
display(Image(filename='images/boosttree6.png'))
display(Image(filename='images/boosttree7.png'))
display(Image(filename='images/boosttree8.png'))
display(Image(filename='images/boosttree9.png'))

# %% [markdown]
# 提升树采用前向分布算法,每次都去拟合前面模型的参差,这点和adaboost有很大的不同,adaboost是每次训练调大预测错误的权值,调小预测正常的权值,使用改变样本分布来训练模型.

# %% [markdown]
# ### 梯度提升树

# %%
display(Image(filename='images/gradboosttree1.png'))
display(Image(filename='images/gradboosttree2.png'))

# %% [markdown]
# 梯度提升树是在提升树的基础上考虑到对于一般的损失函数,步骤计算优化不那么容易,所以采用负梯度来近似残差.

# %% [markdown]
# ### GBDT分类算法

# %%
display(Image(filename='images/classify1.png'))
display(Image(filename='images/classify2.png'))

# %% [markdown]
# ### 损失函数

# %%
display(Image(filename='images/lossfunction1.png'))
display(Image(filename='images/lossfunction2.png'))

# %% [markdown]
# ### GBDT正则化

# %%
display(Image(filename='images/regularization.png'))

# %% [markdown]
# ### 例子

# %%
from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
X,y=make_hastie_10_2(random_state=0)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
clf=GradientBoostingClassifier(n_estimators=100,learning_rate=1.0,max_depth=1,random_state=0)

# %%
clf.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=1.0, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=0, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
clf.score(X_test,y_test)
# Out:
# 0.92500000000000004

# %% [markdown]
# 具体跟其他分类器比较下才能知道,gdbt的性能如何

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
lr.score(X_test,y_test)
# Out:
# 0.51083333333333336

# %%
rf=RandomForestClassifier(n_estimators=200,random_state=0)
rf.fit(X_train,y_train)
rf.score(X_test,y_test)
# Out:
# 0.89958333333333329

# %% [markdown]
# 这里选择了 逻辑回归和随机森林来和gbdt比较,结果显示gbdt分类性能优异
